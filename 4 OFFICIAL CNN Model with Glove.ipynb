# %% [markdown]
# # Set up and Read in Data

# %%
import keras
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

from keras.preprocessing.text import text_to_word_sequence, Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Model
from keras.layers import Layer, Input, Dense, Concatenate, Conv2D, Reshape,  Embedding
from keras.layers import MaxPooling1D, Flatten, BatchNormalization, Activation, Dropout

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix

import matplotlib as mpl
# %matplotlib inline

from matplotlib import pyplot as plt
from keras.utils.vis_utils import plot_model
from IPython.display import Image

import seaborn as sns
from sklearn.metrics import confusion_matrix
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
print(keras.__version__)
# Out:
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_FILE_PATH = 'drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code'

df_train = pd.read_csv(DATA_FILE_PATH+"/train.csv")
df_val = pd.read_csv(DATA_FILE_PATH+"/val.csv")
df_test = pd.read_csv(DATA_FILE_PATH+"/test.csv")

# %%
# Print number in each group.
print("Training: ", len(df_train))
print("Val: ", len(df_val))
print("Test: ", len(df_test))
# Out:
# Training:  50971
# Val:  6471
# Test:  4621

# %%
# To get reproducible results.
from numpy.random import seed
seed(598)

# %% [markdown]
# # Hyperparameters

# %%
EMB_DIR = 'drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/glove.6B.50d.txt'

MAX_VOCAB_SIZE = 10000
MAX_SENT_LEN = 12
EMBEDDING_DIM = 50

# %% [markdown]
# # Preprocessing

# %%
print('Train dataset size:', df_train.shape)

# Convert all values in text column to string.
df_train["text"] = df_train["text"].apply(lambda x: str(x))
df_val["text"] = df_val["text"].apply(lambda x: str(x))
df_test["text"] = df_test["text"].apply(lambda x: str(x))
# Out:
# Train dataset size: (50971, 10)

# %% [markdown]
# #### Delete Small and Long Texts

# %%
df_train['text_length'] = df_train["text"].apply(lambda x: len(x))
df_train[df_train['text_length']<10]['text']
# Out:
# 3        She okay?
# 4        Let's go.
# 5              Wow
# 7               No
# 17           No...
#            ...
# 50950       I know
# 50959          nan
# 50961           Oh
# 50962         Yes.
# 50963         Four
# Name: text, Length: 13546, dtype: object

# %%
# Questions having lesser than 10 characters can be discarded. 
indices = set(df_train[df_train['text_length']<10].index)

df_train.drop(indices, inplace=True)
df_train.reset_index()

# Can drop the character count columns - to save memory
df_train.drop(['text_length'], inplace=True, axis=1)

# %%
# THIS IS HOW WE GOT MAX_SENT_LEN = 12
word_count = lambda x:len(x.split()) # Word count for each utterance
df_train['text_wc'] = df_train.text.str.split().str.len()

p = 80.0

print('Text :{} % of the sentences have a length less than or equal to {}'.format(p, np.nanpercentile(df_train['text_wc'], 80)))
# Out:
# Text :80.0 % of the sentences have a length less than or equal to 11.0

# %% [markdown]
# #### Equalise values in each category

# %%
def equalize_category(category):
  print("Before Equalize:")
  print(df_train[category].value_counts())
  
  min_count = min(df_train[category].value_counts())

  neg = df_train[df_train[category] == 0][:min_count]
  pos = df_train[df_train[category] == 1][:min_count]

  df_train_category = pd.concat([neg, pos])
  df_train_category = df_train_category.sample(frac=1).reset_index(drop=True) # shuffling

  print("\nAfter Equalize:")
  print(df_train_category[category].value_counts())

  return df_train_category

# %%
df_train_IE = equalize_category("IE")
# Out:
# Before Equalize:
# 1    19635
# 0    17790
# Name: IE, dtype: int64
#
# After Equalize:
# 0    17790
# 1    17790
# Name: IE, dtype: int64

# %%
df_train_NS = equalize_category("NS")
# Out:
# Before Equalize:
# 0    19709
# 1    17716
# Name: NS, dtype: int64
#
# After Equalize:
# 1    17716
# 0    17716
# Name: NS, dtype: int64

# %%
df_train_TF = equalize_category("TF")
# Out:
# Before Equalize:
# 0    22022
# 1    15403
# Name: TF, dtype: int64
#
# After Equalize:
# 1    15403
# 0    15403
# Name: TF, dtype: int64

# %%
df_train_JP = equalize_category("JP")
# Out:
# Before Equalize:
# 0    22146
# 1    15279
# Name: JP, dtype: int64
#
# After Equalize:
# 0    15279
# 1    15279
# Name: JP, dtype: int64

# %% [markdown]
# #### Tokenizing

# %% [markdown]
# Better to use NLTK tokenizer first and then Keras word to indices.
#
# We can concatenate NLTK tokens with whitespace (" ".join(...)) and then use keras Tokenizer
#
#
# ---
#
# Keras will do this : 'what is this?' -> ['what', 'is', 'this?']
#
# NLTK will do this : 'what is this?' -> ['what', 'is', 'this', '?']

# %%
def tokenize_category_text(df_train):
  text_list = list(df_train['text'])
  text_list = [' '.join(word_tokenize(q)[:MAX_SENT_LEN]) for q in text_list]

  # Filters
  tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='!"#?$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n') 
  tokenizer.fit_on_texts(text_list)

  print("Number of words in vocabulary:", len(tokenizer.word_index))

  # Limit vocab and idx-word dictionary
  word_index =  word_index = {k: v for k, v in tokenizer.word_index.items() if v < MAX_VOCAB_SIZE}
  idx_to_word = dict((v,k) for k,v in word_index.items())

  X_train = tokenizer.texts_to_sequences(text_list)
  X_train = pad_sequences(X_train, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

  return X_train, word_index, tokenizer

# %%
X_train_IE, word_index_IE, tokenizer_IE = tokenize_category_text(df_train_IE)
# Out:
# Number of words in vocabulary: 11393

# %%
X_train_NS, word_index_NS,tokenizer_NS = tokenize_category_text(df_train_NS)
# Out:
# Number of words in vocabulary: 11435

# %%
X_train_TF, word_index_TF, tokenizer_TF = tokenize_category_text(df_train_TF)
# Out:
# Number of words in vocabulary: 10683

# %%
X_train_JP, word_index_JP, tokenizer_JP = tokenize_category_text(df_train_JP)
# Out:
# Number of words in vocabulary: 10445

# %% [markdown]
# # Embedding Matrix

# %%
# Load GloVe word embeddings 
# Download Link: https://nlp.stanford.edu/projects/glove/

print("[INFO]: Reading Word Embeddings ...")
# Data path
embeddings = {}
f = open(EMB_DIR)
for line in f:
    values = line.split()
    word = values[0]
    vector = np.asarray(values[1:], dtype='float32')
    embeddings[word] = vector
f.close()
# Out:
# [INFO]: Reading Word Embeddings ...

# %%
def create_embedding_matrix(word_index):
  # Create an embedding matrix containing only the word's in our vocabulary
  # If the word does not have a pre-trained embedding, then randomly initialize the embedding
  embeddings_matrix = np.random.uniform(-0.05, 0.05, size=(len(word_index)+1, EMBEDDING_DIM)) # +1 is because the matrix indices start with 0

  for word, i in word_index.items(): # i=0 is the embedding for the zero padding
      try:
          embeddings_vector = embeddings[word]
      except KeyError:
          embeddings_vector = None
      if embeddings_vector is not None:
          embeddings_matrix[i] = embeddings_vector
  return embeddings_matrix

# %% [markdown]
# # CNN with Keras Model API

# %%
# Bigram and trigram filters
bi_filter_size = 2
tri_filter_size = 3

num_filters = 20

# %%
def make_CNN_model(embeddings_matrix):
  input_1 = Input(shape=(MAX_SENT_LEN, ), name='text_input')

  # Common embedding lookup layer
  emb_look_up = Embedding(input_dim=MAX_VOCAB_SIZE,
                          output_dim=EMBEDDING_DIM,
                          weights = [embeddings_matrix], 
                          trainable=False, 
                          mask_zero=False,
                          name='text_embedding_lookup')

  emb_1 = emb_look_up(input_1)

  # Need to be reshaped because the CONV layer assumes 1 dimension as num of channels
  emb_1 = Reshape(target_shape=(1, MAX_SENT_LEN, EMBEDDING_DIM), 
                  name='text_embedding_reshape')(emb_1) 

  # Convolutional Layers
  conv_1_bi =  Conv2D(filters=num_filters, 
                      kernel_size=(bi_filter_size, EMBEDDING_DIM), 
                      padding='valid', 
                      activation='relu', 
                      data_format='channels_first', 
                      name='text_bigram_conv')(emb_1)

  conv_1_tri =  Conv2D(filters=num_filters, 
                      kernel_size=(tri_filter_size, EMBEDDING_DIM), 
                      padding='valid', 
                      activation='relu', 
                      data_format='channels_first', 
                      name='text_trigram_conv')(emb_1)

  # Remove channel dimension before max-pooling operation
  bi_out_timesteps = MAX_SENT_LEN - bi_filter_size + 1
  tri_out_timesteps = MAX_SENT_LEN - tri_filter_size + 1

  conv_1_bi = Reshape(target_shape=(bi_out_timesteps, num_filters), 
                      name='text_bigram_conv_reshape')(conv_1_bi) # (MAX_SENT_LEN - bi_filter_size + 1, num_filters)
  conv_1_tri = Reshape(target_shape=(tri_out_timesteps, num_filters), 
                      name='text_trigram_conv_reshape')(conv_1_tri)

  # Max-pooling Layer
  # Pool across timesteps to get 1 feature per filter, i.e., each filter captures 1 feature about the sentence/question
  max_pool_1_bi = MaxPooling1D(pool_size = bi_out_timesteps, 
                              name='text_bigram_maxpool')(conv_1_bi)
  max_pool_1_tri = MaxPooling1D(pool_size = tri_out_timesteps, 
                                name='text_trigram_maxpool')(conv_1_tri)

  # Merge the features learnt by bi and tri filters
  merged_1 = Concatenate(name='text_maxpool_concat')([max_pool_1_bi, max_pool_1_tri])
  # Inputs dropped out randomly so that there is no heavy dependence on specific features for prediction
  dropout_1 = Dropout(rate=0.2, 
                      name='text_dropout')(merged_1)
  flatten_1 = Flatten(name='text_flatten')(dropout_1)

  # Dense layers
  dense_1 = Dense(units=10, 
                  name='text_dense')(flatten_1)
  bn_1 = BatchNormalization(name='batchnorm')(dense_1)
  relu_1 = Activation(activation='relu', 
                      name='relu_activation')(bn_1)
  dense_1_dropout = Dropout(0.2, 
                            name='dense_dropout')(relu_1)

  output_prob = Dense(units=1, 
                      activation='sigmoid', 
                      name='output_layer')(dense_1_dropout)

  model = Model(inputs=[input_1], outputs=output_prob, name='text_pair_cnn')
  model.summary()

  plot_model(model, to_file='text_pair_cnn_classifier.png', show_layer_names=True)
  Image('text_pair_cnn_classifier.png')

  return model

# %%
def txt_to_indx(txt, tokenizer):
  txt = tokenizer.texts_to_sequences(txt)
  txt = pad_sequences(txt, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

  return txt

# %% [markdown]
# # Run Models

# %%
def run_category_model(category, batch_size, n_epochs):
  df_train_category = equalize_category(category)

  X_train, word_index, tokenizer = tokenize_category_text(df_train_category)

  embeddings_matrix = create_embedding_matrix(word_index)

  model = make_CNN_model(embeddings_matrix)

  X_val = txt_to_indx(df_val["text"], tokenizer)

  y_train_category = df_train_category[category]
  y_val_category = df_val[category]

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  model.fit(x = X_train, 
            y = y_train_category, 
            batch_size=batch_size, 
            epochs=n_epochs, 
            validation_data=(X_val, y_val_category))
  
  # Save model.
  model.save(DATA_FILE_PATH+f"/cnn_models/{category}_model")
  
  X_test = txt_to_indx(df_test["text"], tokenizer)
  y_test_category = df_test[category]

  # Predict on test set and compute accuracy.
  y_pred_category = model.predict(X_test)
  y_pred_category = np.where(y_pred_category > 0.5, 1, 0)

  accuracy = accuracy_score(y_test_category, y_pred_category)

  print("* Accuracy: %.2f%%" % (accuracy * 100.0))

  # Plot confusion matrix
  ax = plt.subplot()
  cm = confusion_matrix(y_test_category, y_pred_category)
  f = sns.heatmap(cm, annot=True, fmt='d')
  ax.set_xlabel('Predicted label')
  ax.set_ylabel('True label')

  return model, accuracy, tokenizer

# %% [markdown]
# #### Using the model

# %%
ie_model, ie_accuracy, ie_tokenizer = run_category_model("IE", 32, 20)
# Out:
# Before Equalize:
# 1    19635
# 0    17790
# Name: IE, dtype: int64
#
# After Equalize:
# 1    17790
# 0    17790
# Name: IE, dtype: int64
# Number of words in vocabulary: 11393
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 1112/1112 [==============================] - 22s 10ms/step - loss: 0.7048 - accuracy: 0.5048 - val_loss: 0.6926 - val_accuracy: 0.5141
# Epoch 2/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6926 - accuracy: 0.5173 - val_loss: 0.6980 - val_accuracy: 0.4366
# Epoch 3/20
# 1112/1112 [==============================] - 10s 9ms/step - loss: 0.6920 - accuracy: 0.5231 - val_loss: 0.6961 - val_accuracy: 0.4602
# Epoch 4/20
# 1112/1112 [==============================] - 11s 10ms/step - loss: 0.6896 - accuracy: 0.5342 - val_loss: 0.6975 - val_accuracy: 0.4936
# Epoch 5/20
# 1112/1112 [==============================] - 9s 9ms/step - loss: 0.6874 - accuracy: 0.5433 - val_loss: 0.6880 - val_accuracy: 0.5545
# Epoch 6/20
# 1112/1112 [==============================] - 10s 9ms/step - loss: 0.6857 - accuracy: 0.5474 - val_loss: 0.6912 - val_accuracy: 0.5471
# Epoch 7/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6834 - accuracy: 0.5551 - val_loss: 0.6861 - val_accuracy: 0.5537
# Epoch 8/20
# 1112/1112 [==============================] - 10s 9ms/step - loss: 0.6805 - accuracy: 0.5589 - val_loss: 0.6980 - val_accuracy: 0.5206
# Epoch 9/20
# 1112/1112 [==============================] - 9s 9ms/step - loss: 0.6781 - accuracy: 0.5649 - val_loss: 0.7050 - val_accuracy: 0.5086
# Epoch 10/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6754 - accuracy: 0.5700 - val_loss: 0.6914 - val_accuracy: 0.5443
# Epoch 11/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6718 - accuracy: 0.5789 - val_loss: 0.6976 - val_accuracy: 0.5319
# Epoch 12/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6696 - accuracy: 0.5797 - val_loss: 0.7086 - val_accuracy: 0.5143
# Epoch 13/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6662 - accuracy: 0.5922 - val_loss: 0.7000 - val_accuracy: 0.5369
# Epoch 14/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6642 - accuracy: 0.5871 - val_loss: 0.7086 - val_accuracy: 0.5123
# Epoch 15/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6604 - accuracy: 0.5920 - val_loss: 0.7005 - val_accuracy: 0.5308
# Epoch 16/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6571 - accuracy: 0.5970 - val_loss: 0.7078 - val_accuracy: 0.5288
# Epoch 17/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6559 - accuracy: 0.5995 - val_loss: 0.7062 - val_accuracy: 0.5358
# Epoch 18/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6545 - accuracy: 0.6016 - val_loss: 0.7069 - val_accuracy: 0.5342
# Epoch 19/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6541 - accuracy: 0.5988 - val_loss: 0.7060 - val_accuracy: 0.5359
# Epoch 20/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6519 - accuracy: 0.6062 - val_loss: 0.7133 - val_accuracy: 0.5284
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/IE_model/assets
# * Accuracy: 51.87%

# %%
ns_model, ns_accuracy, ns_tokenizer = run_category_model("NS", 64, 20)
# Out:
# Before Equalize:
# 0    19709
# 1    17716
# Name: NS, dtype: int64
#
# After Equalize:
# 0    17716
# 1    17716
# Name: NS, dtype: int64
# Number of words in vocabulary: 11435
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 554/554 [==============================] - 6s 9ms/step - loss: 0.7172 - accuracy: 0.5048 - val_loss: 0.6914 - val_accuracy: 0.5233
# Epoch 2/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6967 - accuracy: 0.5081 - val_loss: 0.6973 - val_accuracy: 0.4628
# Epoch 3/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6935 - accuracy: 0.5168 - val_loss: 0.6969 - val_accuracy: 0.4636
# Epoch 4/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6927 - accuracy: 0.5197 - val_loss: 0.6946 - val_accuracy: 0.4927
# Epoch 5/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6901 - accuracy: 0.5310 - val_loss: 0.6957 - val_accuracy: 0.4820
# Epoch 6/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6884 - accuracy: 0.5343 - val_loss: 0.6941 - val_accuracy: 0.5021
# Epoch 7/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6865 - accuracy: 0.5462 - val_loss: 0.6980 - val_accuracy: 0.4913
# Epoch 8/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6842 - accuracy: 0.5463 - val_loss: 0.6982 - val_accuracy: 0.4873
# Epoch 9/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6820 - accuracy: 0.5514 - val_loss: 0.6968 - val_accuracy: 0.4965
# Epoch 10/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6792 - accuracy: 0.5585 - val_loss: 0.6981 - val_accuracy: 0.4913
# Epoch 11/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6753 - accuracy: 0.5652 - val_loss: 0.7048 - val_accuracy: 0.4831
# Epoch 12/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6712 - accuracy: 0.5744 - val_loss: 0.7074 - val_accuracy: 0.4726
# Epoch 13/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6685 - accuracy: 0.5763 - val_loss: 0.7045 - val_accuracy: 0.4939
# Epoch 14/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6660 - accuracy: 0.5765 - val_loss: 0.7103 - val_accuracy: 0.4703
# Epoch 15/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6623 - accuracy: 0.5822 - val_loss: 0.7042 - val_accuracy: 0.4874
# Epoch 16/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6601 - accuracy: 0.5872 - val_loss: 0.7070 - val_accuracy: 0.4791
# Epoch 17/20
# 554/554 [==============================] - 5s 8ms/step - loss: 0.6571 - accuracy: 0.5895 - val_loss: 0.7062 - val_accuracy: 0.4781
# Epoch 18/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6543 - accuracy: 0.5942 - val_loss: 0.7057 - val_accuracy: 0.4920
# Epoch 19/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6529 - accuracy: 0.5940 - val_loss: 0.7065 - val_accuracy: 0.4900
# Epoch 20/20
# 554/554 [==============================] - 5s 9ms/step - loss: 0.6508 - accuracy: 0.5992 - val_loss: 0.7108 - val_accuracy: 0.4910
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/NS_model/assets
# * Accuracy: 50.12%

# %%
tf_model, tf_accuracy, tf_tokenizer = run_category_model("TF", 64, 20)
# Out:
# Before Equalize:
# 0    22022
# 1    15403
# Name: TF, dtype: int64
#
# After Equalize:
# 1    15403
# 0    15403
# Name: TF, dtype: int64
# Number of words in vocabulary: 10683
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 482/482 [==============================] - 6s 10ms/step - loss: 0.7206 - accuracy: 0.5085 - val_loss: 0.7089 - val_accuracy: 0.3905
# Epoch 2/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6966 - accuracy: 0.5146 - val_loss: 0.7095 - val_accuracy: 0.3897
# Epoch 3/20
# 482/482 [==============================] - 5s 10ms/step - loss: 0.6928 - accuracy: 0.5249 - val_loss: 0.6970 - val_accuracy: 0.4616
# Epoch 4/20
# 482/482 [==============================] - 4s 8ms/step - loss: 0.6914 - accuracy: 0.5215 - val_loss: 0.6993 - val_accuracy: 0.4497
# Epoch 5/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6899 - accuracy: 0.5321 - val_loss: 0.7050 - val_accuracy: 0.4196
# Epoch 6/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6879 - accuracy: 0.5438 - val_loss: 0.7143 - val_accuracy: 0.4256
# Epoch 7/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6861 - accuracy: 0.5458 - val_loss: 0.7063 - val_accuracy: 0.4350
# Epoch 8/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6851 - accuracy: 0.5524 - val_loss: 0.7044 - val_accuracy: 0.4279
# Epoch 9/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6822 - accuracy: 0.5587 - val_loss: 0.7041 - val_accuracy: 0.4648
# Epoch 10/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6783 - accuracy: 0.5641 - val_loss: 0.6996 - val_accuracy: 0.4794
# Epoch 11/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6748 - accuracy: 0.5721 - val_loss: 0.6998 - val_accuracy: 0.4947
# Epoch 12/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6694 - accuracy: 0.5824 - val_loss: 0.7083 - val_accuracy: 0.4601
# Epoch 13/20
# 482/482 [==============================] - 4s 8ms/step - loss: 0.6675 - accuracy: 0.5842 - val_loss: 0.7165 - val_accuracy: 0.4516
# Epoch 14/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6637 - accuracy: 0.5893 - val_loss: 0.7275 - val_accuracy: 0.4247
# Epoch 15/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6589 - accuracy: 0.5972 - val_loss: 0.7073 - val_accuracy: 0.4803
# Epoch 16/20
# 482/482 [==============================] - 4s 8ms/step - loss: 0.6558 - accuracy: 0.6022 - val_loss: 0.7073 - val_accuracy: 0.4859
# Epoch 17/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6560 - accuracy: 0.6018 - val_loss: 0.6946 - val_accuracy: 0.5160
# Epoch 18/20
# 482/482 [==============================] - 4s 8ms/step - loss: 0.6522 - accuracy: 0.6064 - val_loss: 0.7251 - val_accuracy: 0.4638
# Epoch 19/20
# 482/482 [==============================] - 4s 9ms/step - loss: 0.6483 - accuracy: 0.6105 - val_loss: 0.7260 - val_accuracy: 0.4469
# Epoch 20/20
# 482/482 [==============================] - 4s 8ms/step - loss: 0.6467 - accuracy: 0.6105 - val_loss: 0.7138 - val_accuracy: 0.4843
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/TF_model/assets
# * Accuracy: 50.25%

# %%
jp_model, jp_accuracy, jp_tokenizer = run_category_model("JP", 64, 20)
# Out:
# Before Equalize:
# 0    22146
# 1    15279
# Name: JP, dtype: int64
#
# After Equalize:
# 0    15279
# 1    15279
# Name: JP, dtype: int64
# Number of words in vocabulary: 10445
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 478/478 [==============================] - 6s 9ms/step - loss: 0.7405 - accuracy: 0.5009 - val_loss: 0.6939 - val_accuracy: 0.5158
# Epoch 2/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.7034 - accuracy: 0.5099 - val_loss: 0.6928 - val_accuracy: 0.5191
# Epoch 3/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6971 - accuracy: 0.5127 - val_loss: 0.6961 - val_accuracy: 0.4959
# Epoch 4/20
# 478/478 [==============================] - 4s 9ms/step - loss: 0.6934 - accuracy: 0.5228 - val_loss: 0.6956 - val_accuracy: 0.5044
# Epoch 5/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6907 - accuracy: 0.5312 - val_loss: 0.6976 - val_accuracy: 0.4868
# Epoch 6/20
# 478/478 [==============================] - 4s 9ms/step - loss: 0.6885 - accuracy: 0.5369 - val_loss: 0.6987 - val_accuracy: 0.4988
# Epoch 7/20
# 478/478 [==============================] - 5s 9ms/step - loss: 0.6871 - accuracy: 0.5383 - val_loss: 0.6904 - val_accuracy: 0.5361
# Epoch 8/20
# 478/478 [==============================] - 6s 12ms/step - loss: 0.6825 - accuracy: 0.5541 - val_loss: 0.6979 - val_accuracy: 0.5063
# Epoch 9/20
# 478/478 [==============================] - 6s 13ms/step - loss: 0.6796 - accuracy: 0.5582 - val_loss: 0.7013 - val_accuracy: 0.5140
# Epoch 10/20
# 478/478 [==============================] - 6s 13ms/step - loss: 0.6769 - accuracy: 0.5605 - val_loss: 0.6992 - val_accuracy: 0.5123
# Epoch 11/20
# 478/478 [==============================] - 6s 12ms/step - loss: 0.6742 - accuracy: 0.5628 - val_loss: 0.7130 - val_accuracy: 0.4664
# Epoch 12/20
# 478/478 [==============================] - 5s 9ms/step - loss: 0.6701 - accuracy: 0.5723 - val_loss: 0.6997 - val_accuracy: 0.5134
# Epoch 13/20
# 478/478 [==============================] - 4s 9ms/step - loss: 0.6670 - accuracy: 0.5784 - val_loss: 0.7011 - val_accuracy: 0.5256
# Epoch 14/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6618 - accuracy: 0.5851 - val_loss: 0.7077 - val_accuracy: 0.5124
# Epoch 15/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6602 - accuracy: 0.5874 - val_loss: 0.7065 - val_accuracy: 0.5166
# Epoch 16/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6553 - accuracy: 0.5928 - val_loss: 0.7045 - val_accuracy: 0.5143
# Epoch 17/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6545 - accuracy: 0.5923 - val_loss: 0.7070 - val_accuracy: 0.5318
# Epoch 18/20
# 478/478 [==============================] - 4s 9ms/step - loss: 0.6520 - accuracy: 0.5979 - val_loss: 0.7114 - val_accuracy: 0.5231
# Epoch 19/20
# 478/478 [==============================] - 4s 9ms/step - loss: 0.6493 - accuracy: 0.6001 - val_loss: 0.7186 - val_accuracy: 0.5206
# Epoch 20/20
# 478/478 [==============================] - 4s 8ms/step - loss: 0.6463 - accuracy: 0.6035 - val_loss: 0.7181 - val_accuracy: 0.5087
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/JP_model/assets
# * Accuracy: 49.77%

# %% [markdown]
# ### Accuracy Values

# %%
# Macroaverage accuracy of the four classifiers.
macroavg_accuracy = (ie_accuracy + jp_accuracy + ns_accuracy + tf_accuracy) / 4
print("* Macroaverage Accuracy: %.2f%%" % (macroavg_accuracy * 100.0))
# Out:
# * Macroaverage Accuracy: 50.50%

# %%
# Microaverage accuracy of the four classifiers.
microavg_accuracy = ((664+1733)+(1109+1191)+(853+1463)+(1100+1222)) / (4*len(df_test))
print("* Microaverage Accuracy: %.2f%%" % (microavg_accuracy * 100.0))
# Out:
# * Microaverage Accuracy: 50.50%

# %%
df_results = df_test

X_test_ie = txt_to_indx(df_test["text"], ie_tokenizer)
y_pred_ie = ie_model.predict(X_test_ie)
df_results["IE_pred"] = np.where(y_pred_ie > 0.5, 1, 0)

X_test_ns = txt_to_indx(df_test["text"], ns_tokenizer)
y_pred_ns = ns_model.predict(X_test_ns)
df_results["NS_pred"] = np.where(y_pred_ns > 0.5, 1, 0)

X_test_tf = txt_to_indx(df_test["text"], tf_tokenizer)
y_pred_tf = tf_model.predict(X_test_tf)
df_results["TF_pred"] = np.where(y_pred_tf > 0.5, 1, 0)

X_test_jp = txt_to_indx(df_test["text"], jp_tokenizer)
y_pred_jp = jp_model.predict(X_test_jp)
df_results["JP_pred"] = np.where(y_pred_jp > 0.5, 1, 0)

full_match = df_results[(df_results["IE"] == df_results["IE_pred"]) & (df_results["NS"] == df_results["NS_pred"]) & (df_results["TF"] == df_results["TF_pred"]) & (df_results["JP"] == df_results["JP_pred"])].count()["text"]
print("* Full Match Accuracy: %.2f%%" % (full_match/len(df_test) * 100.0))
# Out:
# * Full Match Accuracy: 7.14%

# %%
df_results
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0            860          6334
# 1            861          6336
# 2            862          6338
# 3            863          6340
# 4            864          6342
# ...          ...           ...
# 4616       62696        300591
# 4617       62697        300592
# 4618       63144        305902
# 4619       63145        305904
# 4620       63146        305906
#
#                                                    text              role  \
# 0                I feel wrong. I feel wrong being here.  Constanze Mozart
# 1                                                  Yes!  Constanze Mozart
# 2                          I want to go back to Vienna.  Constanze Mozart
# 3                                         I want to go!  Constanze Mozart
# 4     Please! Let me sit here. Let me stay here with...  Constanze Mozart
# ...                                                 ...               ...
# 4616                         Take your time. Enjoy L.A.           Redfoot
# 4617         I've got a ton of work and no good people.           Redfoot
# 4618                                                :Oh     Nick Marshall
# 4619                                              :Well     Nick Marshall
# 4620                                                :No     Nick Marshall
#
#              movie_clean  mbti  IE  NS  TF  JP  IE_pred  NS_pred  TF_pred  \
# 0                amadeus  ESFJ   0   0   0   1        1        1        0
# 1                amadeus  ESFJ   0   0   0   1        1        1        0
# 2                amadeus  ESFJ   0   0   0   1        1        1        0
# 3                amadeus  ESFJ   0   0   0   1        1        1        0
# 4                amadeus  ESFJ   0   0   0   1        0        1        1
# ...                  ...   ...  ..  ..  ..  ..      ...      ...      ...
# 4616  the usual suspects  ESTP   0   0   1   0        0        1        0
# 4617  the usual suspects  ESTP   0   0   1   0        1        1        0
# 4618     what women want  ENTP   0   1   1   0        0        1        0
# 4619     what women want  ENTP   0   1   1   0        1        1        1
# 4620     what women want  ENTP   0   1   1   0        1        0        1
#
#       JP_pred
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 4616        1
# 4617        1
# 4618        0
# 4619        0
# 4620        1
#
# [4621 rows x 14 columns]

# %%
df_results.to_csv(DATA_FILE_PATH+"/cnn_best_pred.csv")
