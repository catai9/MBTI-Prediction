# %% [markdown]
# # Set up and Read in Data

# %%
import keras
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

from keras.preprocessing.text import text_to_word_sequence, Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Model
from keras.layers import Layer, Input, Dense, Concatenate, Conv2D, Reshape,  Embedding
from keras.layers import MaxPooling1D, Flatten, BatchNormalization, Activation, Dropout

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix

import matplotlib as mpl
# %matplotlib inline

from matplotlib import pyplot as plt
from keras.utils.vis_utils import plot_model
from IPython.display import Image

import seaborn as sns
from sklearn.metrics import confusion_matrix
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
print(keras.__version__)
# Out:
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_FILE_PATH = 'drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code'

df_train = pd.read_csv(DATA_FILE_PATH+"/train.csv")
df_val = pd.read_csv(DATA_FILE_PATH+"/val.csv")
df_test = pd.read_csv(DATA_FILE_PATH+"/test.csv")

# %%
# Print number in each group.
print("Training: ", len(df_train))
print("Val: ", len(df_val))
print("Test: ", len(df_test))
# Out:
# Training:  50971
# Val:  6471
# Test:  4621

# %%
# To get reproducible results.
from numpy.random import seed
seed(598)

# %% [markdown]
# # Hyperparameters

# %%
EMB_DIR = 'drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/glove.6B.50d.txt'

MAX_VOCAB_SIZE = 10000
MAX_SENT_LEN = 12
EMBEDDING_DIM = 50
BATCH_SIZE = 32
N_EPOCHS = 20

# %% [markdown]
# # Preprocessing

# %%
print('Train dataset size:', df_train.shape)

# Convert all values in text column to string.
df_train["text"] = df_train["text"].apply(lambda x: str(x))
df_val["text"] = df_val["text"].apply(lambda x: str(x))
df_test["text"] = df_test["text"].apply(lambda x: str(x))
# Out:
# Train dataset size: (50971, 10)

# %% [markdown]
# #### Delete Small and Long Texts

# %%
df_train['text_length'] = df_train["text"].apply(lambda x: len(x))
df_train[df_train['text_length']<10]['text']
# Out:
# 3        She okay?
# 4        Let's go.
# 5              Wow
# 7               No
# 17           No...
#            ...
# 50950       I know
# 50959          nan
# 50961           Oh
# 50962         Yes.
# 50963         Four
# Name: text, Length: 13546, dtype: object

# %%
# Questions having lesser than 10 characters can be discarded. 
indices = set(df_train[df_train['text_length']<10].index)

df_train.drop(indices, inplace=True)
df_train.reset_index()

# Can drop the character count columns - to save memory
df_train.drop(['text_length'], inplace=True, axis=1)

# %%
# THIS IS HOW WE GOT MAX_SENT_LEN = 12
word_count = lambda x:len(x.split()) # Word count for each utterance
df_train['text_wc'] = df_train.text.str.split().str.len()

p = 80.0

print('Text :{} % of the sentences have a length less than or equal to {}'.format(p, np.nanpercentile(df_train['text_wc'], 80)))
# Out:
# Text :80.0 % of the sentences have a length less than or equal to 11.0

# %% [markdown]
# #### Equalise values in each category

# %%
def equalize_category(category):
  print("Before Equalize:")
  print(df_train[category].value_counts())
  
  min_count = min(df_train[category].value_counts())

  neg = df_train[df_train[category] == 0][:min_count]
  pos = df_train[df_train[category] == 1][:min_count]

  df_train_category = pd.concat([neg, pos])
  df_train_category = df_train_category.sample(frac=1).reset_index(drop=True) # shuffling

  print("\nAfter Equalize:")
  print(df_train_category[category].value_counts())

  return df_train_category

# %%
df_train_IE = equalize_category("IE")
# Out:
# Before Equalize:
# 1    19635
# 0    17790
# Name: IE, dtype: int64
#
# After Equalize:
# 0    17790
# 1    17790
# Name: IE, dtype: int64

# %%
df_train_NS = equalize_category("NS")
# Out:
# Before Equalize:
# 0    19709
# 1    17716
# Name: NS, dtype: int64
#
# After Equalize:
# 1    17716
# 0    17716
# Name: NS, dtype: int64

# %%
df_train_TF = equalize_category("TF")
# Out:
# Before Equalize:
# 0    22022
# 1    15403
# Name: TF, dtype: int64
#
# After Equalize:
# 1    15403
# 0    15403
# Name: TF, dtype: int64

# %%
df_train_JP = equalize_category("JP")
# Out:
# Before Equalize:
# 0    22146
# 1    15279
# Name: JP, dtype: int64
#
# After Equalize:
# 0    15279
# 1    15279
# Name: JP, dtype: int64

# %% [markdown]
# #### Tokenizing

# %% [markdown]
# Better to use NLTK tokenizer first and then Keras word to indices.
#
# We can concatenate NLTK tokens with whitespace (" ".join(...)) and then use keras Tokenizer
#
#
# ---
#
# Keras will do this : 'what is this?' -> ['what', 'is', 'this?']
#
# NLTK will do this : 'what is this?' -> ['what', 'is', 'this', '?']

# %%
def tokenize_category_text(df_train):
  text_list = list(df_train['text'])
  text_list = [' '.join(word_tokenize(q)[:MAX_SENT_LEN]) for q in text_list]

  # Filters
  tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='!"#?$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n') 
  tokenizer.fit_on_texts(text_list)

  print("Number of words in vocabulary:", len(tokenizer.word_index))

  # Limit vocab and idx-word dictionary
  word_index =  word_index = {k: v for k, v in tokenizer.word_index.items() if v < MAX_VOCAB_SIZE}
  idx_to_word = dict((v,k) for k,v in word_index.items())

  X_train = tokenizer.texts_to_sequences(text_list)
  X_train = pad_sequences(X_train, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

  return X_train, word_index, tokenizer

# %%
X_train_IE, word_index_IE, tokenizer_IE = tokenize_category_text(df_train_IE)
# Out:
# Number of words in vocabulary: 11393

# %%
X_train_NS, word_index_NS,tokenizer_NS = tokenize_category_text(df_train_NS)
# Out:
# Number of words in vocabulary: 11435

# %%
X_train_TF, word_index_TF, tokenizer_TF = tokenize_category_text(df_train_TF)
# Out:
# Number of words in vocabulary: 10683

# %%
X_train_JP, word_index_JP, tokenizer_JP = tokenize_category_text(df_train_JP)
# Out:
# Number of words in vocabulary: 10445

# %% [markdown]
# # Embedding Matrix

# %%
# Load GloVe word embeddings 
# Download Link: https://nlp.stanford.edu/projects/glove/

print("[INFO]: Reading Word Embeddings ...")
# Data path
embeddings = {}
f = open(EMB_DIR)
for line in f:
    values = line.split()
    word = values[0]
    vector = np.asarray(values[1:], dtype='float32')
    embeddings[word] = vector
f.close()
# Out:
# [INFO]: Reading Word Embeddings ...

# %%
def create_embedding_matrix(word_index):
  # Create an embedding matrix containing only the word's in our vocabulary
  # If the word does not have a pre-trained embedding, then randomly initialize the embedding
  embeddings_matrix = np.random.uniform(-0.05, 0.05, size=(len(word_index)+1, EMBEDDING_DIM)) # +1 is because the matrix indices start with 0

  for word, i in word_index.items(): # i=0 is the embedding for the zero padding
      try:
          embeddings_vector = embeddings[word]
      except KeyError:
          embeddings_vector = None
      if embeddings_vector is not None:
          embeddings_matrix[i] = embeddings_vector
  return embeddings_matrix

# %% [markdown]
# # CNN with Keras Model API

# %%
# Bigram and trigram filters
bi_filter_size = 2
tri_filter_size = 3

num_filters = 20

# %%
def make_CNN_model(embeddings_matrix):
  input_1 = Input(shape=(MAX_SENT_LEN, ), name='text_input')

  # Common embedding lookup layer
  emb_look_up = Embedding(input_dim=MAX_VOCAB_SIZE,
                          output_dim=EMBEDDING_DIM,
                          weights = [embeddings_matrix], 
                          trainable=False, 
                          mask_zero=False,
                          name='text_embedding_lookup')

  emb_1 = emb_look_up(input_1)

  # Need to be reshaped because the CONV layer assumes 1 dimension as num of channels
  emb_1 = Reshape(target_shape=(1, MAX_SENT_LEN, EMBEDDING_DIM), 
                  name='text_embedding_reshape')(emb_1) 

  # Convolutional Layers
  conv_1_bi =  Conv2D(filters=num_filters, 
                      kernel_size=(bi_filter_size, EMBEDDING_DIM), 
                      padding='valid', 
                      activation='relu', 
                      data_format='channels_first', 
                      name='text_bigram_conv')(emb_1)

  conv_1_tri =  Conv2D(filters=num_filters, 
                      kernel_size=(tri_filter_size, EMBEDDING_DIM), 
                      padding='valid', 
                      activation='relu', 
                      data_format='channels_first', 
                      name='text_trigram_conv')(emb_1)

  # Remove channel dimension before max-pooling operation
  bi_out_timesteps = MAX_SENT_LEN - bi_filter_size + 1
  tri_out_timesteps = MAX_SENT_LEN - tri_filter_size + 1

  conv_1_bi = Reshape(target_shape=(bi_out_timesteps, num_filters), 
                      name='text_bigram_conv_reshape')(conv_1_bi) # (MAX_SENT_LEN - bi_filter_size + 1, num_filters)
  conv_1_tri = Reshape(target_shape=(tri_out_timesteps, num_filters), 
                      name='text_trigram_conv_reshape')(conv_1_tri)

  # Max-pooling Layer
  # Pool across timesteps to get 1 feature per filter, i.e., each filter captures 1 feature about the sentence/question
  max_pool_1_bi = MaxPooling1D(pool_size = bi_out_timesteps, 
                              name='text_bigram_maxpool')(conv_1_bi)
  max_pool_1_tri = MaxPooling1D(pool_size = tri_out_timesteps, 
                                name='text_trigram_maxpool')(conv_1_tri)

  # Merge the features learnt by bi and tri filters
  merged_1 = Concatenate(name='text_maxpool_concat')([max_pool_1_bi, max_pool_1_tri])
  # Inputs dropped out randomly so that there is no heavy dependence on specific features for prediction
  dropout_1 = Dropout(rate=0.2, 
                      name='text_dropout')(merged_1)
  flatten_1 = Flatten(name='text_flatten')(dropout_1)

  # Dense layers
  dense_1 = Dense(units=10, 
                  name='text_dense')(flatten_1)
  bn_1 = BatchNormalization(name='batchnorm')(dense_1)
  relu_1 = Activation(activation='relu', 
                      name='relu_activation')(bn_1)
  dense_1_dropout = Dropout(0.2, 
                            name='dense_dropout')(relu_1)

  output_prob = Dense(units=1, 
                      activation='sigmoid', 
                      name='output_layer')(dense_1_dropout)

  model = Model(inputs=[input_1], outputs=output_prob, name='text_pair_cnn')
  model.summary()

  plot_model(model, to_file='text_pair_cnn_classifier.png', show_layer_names=True)
  Image('text_pair_cnn_classifier.png')

  return model

# %%
def txt_to_indx(txt, tokenizer):
  txt = tokenizer.texts_to_sequences(txt)
  txt = pad_sequences(txt, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

  return txt

# %% [markdown]
# # Run Models

# %%
def run_category_model(category):
  df_train_category = equalize_category(category)

  X_train, word_index, tokenizer = tokenize_category_text(df_train_category)

  embeddings_matrix = create_embedding_matrix(word_index)

  model = make_CNN_model(embeddings_matrix)

  X_val = txt_to_indx(df_val["text"], tokenizer)

  y_train_category = df_train_category[category]
  y_val_category = df_val[category]

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  model.fit(x = X_train, 
            y = y_train_category, 
            batch_size=BATCH_SIZE, 
            epochs=N_EPOCHS, 
            validation_data=(X_val, y_val_category))
  
  # Save model.
  model.save(DATA_FILE_PATH+f"/cnn_models/{category}_model")
  
  X_test = txt_to_indx(df_test["text"], tokenizer)
  y_test_category = df_test[category]

  # Predict on test set and compute accuracy.
  y_pred_category = model.predict(X_test)
  y_pred_category = np.where(y_pred_category > 0.5, 1, 0)

  accuracy = accuracy_score(y_test_category, y_pred_category)

  print("* Accuracy: %.2f%%" % (accuracy * 100.0))

  # Plot confusion matrix
  ax = plt.subplot()
  cm = confusion_matrix(y_test_category, y_pred_category)
  f = sns.heatmap(cm, annot=True, fmt='d')
  ax.set_xlabel('Predicted label')
  ax.set_ylabel('True label')

  return model, accuracy, tokenizer

# %% [markdown]
# #### Using the model

# %%
ie_model, ie_accuracy, ie_tokenizer = run_category_model("IE")
# Out:
# Before Equalize:
# 1    19635
# 0    17790
# Name: IE, dtype: int64
#
# After Equalize:
# 1    17790
# 0    17790
# Name: IE, dtype: int64
# Number of words in vocabulary: 11393
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 1112/1112 [==============================] - 19s 7ms/step - loss: 0.7173 - accuracy: 0.5060 - val_loss: 0.7009 - val_accuracy: 0.4389
# Epoch 2/20
# 1112/1112 [==============================] - 7s 7ms/step - loss: 0.6960 - accuracy: 0.5112 - val_loss: 0.6967 - val_accuracy: 0.4934
# Epoch 3/20
# 1112/1112 [==============================] - 7s 7ms/step - loss: 0.6918 - accuracy: 0.5248 - val_loss: 0.6951 - val_accuracy: 0.4783
# Epoch 4/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6904 - accuracy: 0.5295 - val_loss: 0.6921 - val_accuracy: 0.5194
# Epoch 5/20
# 1112/1112 [==============================] - 8s 7ms/step - loss: 0.6884 - accuracy: 0.5396 - val_loss: 0.6912 - val_accuracy: 0.5565
# Epoch 6/20
# 1112/1112 [==============================] - 9s 8ms/step - loss: 0.6866 - accuracy: 0.5447 - val_loss: 0.6948 - val_accuracy: 0.5260
# Epoch 7/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6850 - accuracy: 0.5478 - val_loss: 0.6953 - val_accuracy: 0.5223
# Epoch 8/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6828 - accuracy: 0.5565 - val_loss: 0.6981 - val_accuracy: 0.5132
# Epoch 9/20
# 1112/1112 [==============================] - 7s 7ms/step - loss: 0.6810 - accuracy: 0.5578 - val_loss: 0.7052 - val_accuracy: 0.5032
# Epoch 10/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6769 - accuracy: 0.5669 - val_loss: 0.6993 - val_accuracy: 0.5140
# Epoch 11/20
# 1112/1112 [==============================] - 7s 7ms/step - loss: 0.6755 - accuracy: 0.5702 - val_loss: 0.6971 - val_accuracy: 0.5469
# Epoch 12/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6727 - accuracy: 0.5752 - val_loss: 0.6965 - val_accuracy: 0.5352
# Epoch 13/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6711 - accuracy: 0.5779 - val_loss: 0.7043 - val_accuracy: 0.5359
# Epoch 14/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6681 - accuracy: 0.5829 - val_loss: 0.7023 - val_accuracy: 0.5506
# Epoch 15/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6652 - accuracy: 0.5878 - val_loss: 0.7064 - val_accuracy: 0.5240
# Epoch 16/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6629 - accuracy: 0.5902 - val_loss: 0.6980 - val_accuracy: 0.5401
# Epoch 17/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6599 - accuracy: 0.5962 - val_loss: 0.7038 - val_accuracy: 0.5310
# Epoch 18/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6585 - accuracy: 0.5997 - val_loss: 0.6983 - val_accuracy: 0.5596
# Epoch 19/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6555 - accuracy: 0.6038 - val_loss: 0.7007 - val_accuracy: 0.5540
# Epoch 20/20
# 1112/1112 [==============================] - 7s 6ms/step - loss: 0.6530 - accuracy: 0.6057 - val_loss: 0.7078 - val_accuracy: 0.5528
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/IE_model/assets
# * Accuracy: 52.93%

# %%
ns_model, ns_accuracy, ns_tokenizer = run_category_model("NS")
# Out:
# Before Equalize:
# 0    19709
# 1    17716
# Name: NS, dtype: int64
#
# After Equalize:
# 0    17716
# 1    17716
# Name: NS, dtype: int64
# Number of words in vocabulary: 11435
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 1108/1108 [==============================] - 8s 7ms/step - loss: 0.7037 - accuracy: 0.5066 - val_loss: 0.6961 - val_accuracy: 0.4720
# Epoch 2/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6946 - accuracy: 0.5080 - val_loss: 0.6970 - val_accuracy: 0.4953
# Epoch 3/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6915 - accuracy: 0.5237 - val_loss: 0.6926 - val_accuracy: 0.5182
# Epoch 4/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6898 - accuracy: 0.5306 - val_loss: 0.6947 - val_accuracy: 0.5112
# Epoch 5/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6888 - accuracy: 0.5312 - val_loss: 0.6947 - val_accuracy: 0.5172
# Epoch 6/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6856 - accuracy: 0.5427 - val_loss: 0.7022 - val_accuracy: 0.4862
# Epoch 7/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6827 - accuracy: 0.5520 - val_loss: 0.6945 - val_accuracy: 0.5268
# Epoch 8/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6804 - accuracy: 0.5541 - val_loss: 0.6934 - val_accuracy: 0.5134
# Epoch 9/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6774 - accuracy: 0.5631 - val_loss: 0.6995 - val_accuracy: 0.4947
# Epoch 10/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6749 - accuracy: 0.5637 - val_loss: 0.6959 - val_accuracy: 0.5146
# Epoch 11/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6710 - accuracy: 0.5758 - val_loss: 0.6969 - val_accuracy: 0.5126
# Epoch 12/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6692 - accuracy: 0.5738 - val_loss: 0.7019 - val_accuracy: 0.4979
# Epoch 13/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6667 - accuracy: 0.5781 - val_loss: 0.7052 - val_accuracy: 0.4968
# Epoch 14/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6629 - accuracy: 0.5817 - val_loss: 0.7075 - val_accuracy: 0.4907
# Epoch 15/20
# 1108/1108 [==============================] - 7s 7ms/step - loss: 0.6603 - accuracy: 0.5855 - val_loss: 0.7071 - val_accuracy: 0.5018
# Epoch 16/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6601 - accuracy: 0.5883 - val_loss: 0.7068 - val_accuracy: 0.4936
# Epoch 17/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6557 - accuracy: 0.5926 - val_loss: 0.7133 - val_accuracy: 0.4843
# Epoch 18/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6557 - accuracy: 0.5889 - val_loss: 0.7103 - val_accuracy: 0.4823
# Epoch 19/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6527 - accuracy: 0.5950 - val_loss: 0.7126 - val_accuracy: 0.4808
# Epoch 20/20
# 1108/1108 [==============================] - 7s 6ms/step - loss: 0.6515 - accuracy: 0.6008 - val_loss: 0.7130 - val_accuracy: 0.4927
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/NS_model/assets
# * Accuracy: 49.86%

# %%
tf_model, tf_accuracy, tf_tokenizer = run_category_model("TF")
# Out:
# Before Equalize:
# 0    22022
# 1    15403
# Name: TF, dtype: int64
#
# After Equalize:
# 1    15403
# 0    15403
# Name: TF, dtype: int64
# Number of words in vocabulary: 10683
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 963/963 [==============================] - 8s 7ms/step - loss: 0.7099 - accuracy: 0.5077 - val_loss: 0.7015 - val_accuracy: 0.4591
# Epoch 2/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6922 - accuracy: 0.5227 - val_loss: 0.7002 - val_accuracy: 0.4678
# Epoch 3/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6896 - accuracy: 0.5329 - val_loss: 0.6949 - val_accuracy: 0.4792
# Epoch 4/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6869 - accuracy: 0.5394 - val_loss: 0.7015 - val_accuracy: 0.4616
# Epoch 5/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6835 - accuracy: 0.5536 - val_loss: 0.7109 - val_accuracy: 0.4755
# Epoch 6/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6809 - accuracy: 0.5602 - val_loss: 0.6952 - val_accuracy: 0.5367
# Epoch 7/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6768 - accuracy: 0.5681 - val_loss: 0.7088 - val_accuracy: 0.4454
# Epoch 8/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6741 - accuracy: 0.5710 - val_loss: 0.7047 - val_accuracy: 0.4720
# Epoch 9/20
# 963/963 [==============================] - 6s 7ms/step - loss: 0.6699 - accuracy: 0.5796 - val_loss: 0.6958 - val_accuracy: 0.4978
# Epoch 10/20
# 963/963 [==============================] - 6s 7ms/step - loss: 0.6659 - accuracy: 0.5834 - val_loss: 0.6889 - val_accuracy: 0.5310
# Epoch 11/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6633 - accuracy: 0.5867 - val_loss: 0.6945 - val_accuracy: 0.5178
# Epoch 12/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6596 - accuracy: 0.5898 - val_loss: 0.7012 - val_accuracy: 0.5341
# Epoch 13/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6563 - accuracy: 0.5952 - val_loss: 0.6988 - val_accuracy: 0.4718
# Epoch 14/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6536 - accuracy: 0.5948 - val_loss: 0.6964 - val_accuracy: 0.5144
# Epoch 15/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6518 - accuracy: 0.6025 - val_loss: 0.6992 - val_accuracy: 0.4917
# Epoch 16/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6480 - accuracy: 0.6043 - val_loss: 0.7003 - val_accuracy: 0.4778
# Epoch 17/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6097 - val_loss: 0.6916 - val_accuracy: 0.5036
# Epoch 18/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6040 - val_loss: 0.6997 - val_accuracy: 0.5495
# Epoch 19/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6429 - accuracy: 0.6143 - val_loss: 0.7086 - val_accuracy: 0.4808
# Epoch 20/20
# 963/963 [==============================] - 6s 6ms/step - loss: 0.6416 - accuracy: 0.6143 - val_loss: 0.6943 - val_accuracy: 0.4992
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/TF_model/assets
# * Accuracy: 50.57%

# %%
jp_model, jp_accuracy, jp_tokenizer = run_category_model("JP")
# Out:
# Before Equalize:
# 0    22146
# 1    15279
# Name: JP, dtype: int64
#
# After Equalize:
# 0    15279
# 1    15279
# Name: JP, dtype: int64
# Number of words in vocabulary: 10445
# Model: "text_pair_cnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 12)]         0           []
#
#  text_embedding_lookup (Embeddi  (None, 12, 50)      500000      ['text_input[0][0]']
#  ng)
#
#  text_embedding_reshape (Reshap  (None, 1, 12, 50)   0           ['text_embedding_lookup[0][0]']
#  e)
#
#  text_bigram_conv (Conv2D)      (None, 20, 11, 1)    2020        ['text_embedding_reshape[0][0]']
#
#  text_trigram_conv (Conv2D)     (None, 20, 10, 1)    3020        ['text_embedding_reshape[0][0]']
#
#  text_bigram_conv_reshape (Resh  (None, 11, 20)      0           ['text_bigram_conv[0][0]']
#  ape)
#
#  text_trigram_conv_reshape (Res  (None, 10, 20)      0           ['text_trigram_conv[0][0]']
#  hape)
#
#  text_bigram_maxpool (MaxPoolin  (None, 1, 20)       0           ['text_bigram_conv_reshape[0][0]'
#  g1D)                                                            ]
#
#  text_trigram_maxpool (MaxPooli  (None, 1, 20)       0           ['text_trigram_conv_reshape[0][0]
#  ng1D)                                                           ']
#
#  text_maxpool_concat (Concatena  (None, 1, 40)       0           ['text_bigram_maxpool[0][0]',
#  te)                                                              'text_trigram_maxpool[0][0]']
#
#  text_dropout (Dropout)         (None, 1, 40)        0           ['text_maxpool_concat[0][0]']
#
#  text_flatten (Flatten)         (None, 40)           0           ['text_dropout[0][0]']
#
#  text_dense (Dense)             (None, 10)           410         ['text_flatten[0][0]']
#
#  batchnorm (BatchNormalization)  (None, 10)          40          ['text_dense[0][0]']
#
#  relu_activation (Activation)   (None, 10)           0           ['batchnorm[0][0]']
#
#  dense_dropout (Dropout)        (None, 10)           0           ['relu_activation[0][0]']
#
#  output_layer (Dense)           (None, 1)            11          ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 505,501
# Trainable params: 5,481
# Non-trainable params: 500,020
# __________________________________________________________________________________________________
# Epoch 1/20
# 955/955 [==============================] - 7s 7ms/step - loss: 0.7247 - accuracy: 0.4989 - val_loss: 0.6863 - val_accuracy: 0.5608
# Epoch 2/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6972 - accuracy: 0.5077 - val_loss: 0.6898 - val_accuracy: 0.5537
# Epoch 3/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6934 - accuracy: 0.5153 - val_loss: 0.6901 - val_accuracy: 0.5463
# Epoch 4/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6918 - accuracy: 0.5198 - val_loss: 0.6880 - val_accuracy: 0.5588
# Epoch 5/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6896 - accuracy: 0.5298 - val_loss: 0.6902 - val_accuracy: 0.5369
# Epoch 6/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6876 - accuracy: 0.5412 - val_loss: 0.6922 - val_accuracy: 0.5316
# Epoch 7/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6848 - accuracy: 0.5487 - val_loss: 0.6973 - val_accuracy: 0.5100
# Epoch 8/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6818 - accuracy: 0.5510 - val_loss: 0.6881 - val_accuracy: 0.5523
# Epoch 9/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6786 - accuracy: 0.5599 - val_loss: 0.6968 - val_accuracy: 0.5219
# Epoch 10/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6757 - accuracy: 0.5676 - val_loss: 0.6963 - val_accuracy: 0.5322
# Epoch 11/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6725 - accuracy: 0.5753 - val_loss: 0.6938 - val_accuracy: 0.5401
# Epoch 12/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6693 - accuracy: 0.5755 - val_loss: 0.7036 - val_accuracy: 0.5110
# Epoch 13/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6681 - accuracy: 0.5786 - val_loss: 0.7017 - val_accuracy: 0.5250
# Epoch 14/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6639 - accuracy: 0.5864 - val_loss: 0.7022 - val_accuracy: 0.5288
# Epoch 15/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6616 - accuracy: 0.5881 - val_loss: 0.6991 - val_accuracy: 0.5291
# Epoch 16/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6607 - accuracy: 0.5946 - val_loss: 0.7025 - val_accuracy: 0.5348
# Epoch 17/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6576 - accuracy: 0.5905 - val_loss: 0.7039 - val_accuracy: 0.5273
# Epoch 18/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6573 - accuracy: 0.5949 - val_loss: 0.7017 - val_accuracy: 0.5373
# Epoch 19/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6550 - accuracy: 0.5969 - val_loss: 0.7068 - val_accuracy: 0.5134
# Epoch 20/20
# 955/955 [==============================] - 6s 6ms/step - loss: 0.6520 - accuracy: 0.5995 - val_loss: 0.7074 - val_accuracy: 0.5285
# INFO:tensorflow:Assets written to: drive/MyDrive/4B Projects/MSCI 598 (Deep Learning for NLP) Project/Code/cnn_models/JP_model/assets
# * Accuracy: 48.71%

# %% [markdown]
# ### Accuracy Values

# %%
# Macroaverage accuracy of the four classifiers.
macroavg_accuracy = (ie_accuracy + jp_accuracy + ns_accuracy + tf_accuracy) / 4
print("* Macroaverage Accuracy: %.2f%%" % (macroavg_accuracy * 100.0))
# Out:
# * Macroaverage Accuracy: 50.52%

# %%
# Microaverage accuracy of the four classifiers.
microavg_accuracy = ((685+1761)+(792+1512)+(1126+1211)+(1466+785)) / (4*len(df_test))
print("* Microaverage Accuracy: %.2f%%" % (microavg_accuracy * 100.0))
# Out:
# * Microaverage Accuracy: 50.52%

# %%
df_results = df_test

X_test_ie = txt_to_indx(df_test["text"], ie_tokenizer)
y_pred_ie = ie_model.predict(X_test_ie)
df_results["IE_pred"] = np.where(y_pred_ie > 0.5, 1, 0)

X_test_ns = txt_to_indx(df_test["text"], ns_tokenizer)
y_pred_ns = ns_model.predict(X_test_ns)
df_results["NS_pred"] = np.where(y_pred_ns > 0.5, 1, 0)

X_test_tf = txt_to_indx(df_test["text"], tf_tokenizer)
y_pred_tf = tf_model.predict(X_test_tf)
df_results["TF_pred"] = np.where(y_pred_tf > 0.5, 1, 0)

X_test_jp = txt_to_indx(df_test["text"], jp_tokenizer)
y_pred_jp = jp_model.predict(X_test_jp)
df_results["JP_pred"] = np.where(y_pred_jp > 0.5, 1, 0)

full_match = df_results[(df_results["IE"] == df_results["IE_pred"]) & (df_results["NS"] == df_results["NS_pred"]) & (df_results["TF"] == df_results["TF_pred"]) & (df_results["JP"] == df_results["JP_pred"])].count()["text"]
print("* Full Match Accuracy: %.2f%%" % (full_match/len(df_test) * 100.0))
# Out:
# * Full Match Accuracy: 6.58%
